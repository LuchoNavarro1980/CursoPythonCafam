# %% [markdown]
# ![images.png](data:image/png;base64,...)
#
#
# **LIBRERIAS**
#
# CURSO DE PYTHON
#
# DIRECCION DE EDUCACIÓN CONTINUA
#
# FUNDACION UNIVERSITARIA CAFAM
#
# DOCENTE: NICOLAS MOJICA GOMEZ
#
# ESTUDIANTE: **LUIS GONZALO NAVARRO P.**
#
#
# ---

# %%
import pandas as pd

ejecuciones = pd.read_excel("/content/sample_data/Base ejecuciones Oct-17.xlsx")

# %%
planta = pd.read_excel("//content/sample_data/Planta.xlsx")
horas = pd.read_excel("/content/sample_data/Punto # 3.xlsx")
prestamo = pd.read_excel("/content/sample_data/Punto # 4.xlsx")
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
ejecuciones
# Out:
#            CEDULA  N° Cuentas  N° CDT  N° Tarjetas De Crédito  \
# 0    9.375240e+06          64       2                      12
# 1    1.023008e+09          93       6                      16
# 2    4.196091e+07          61       3                      10
# 3    1.010229e+09          63       2                      14
# 4    1.054920e+09          80       3                      15
# ..            ...         ...     ...                     ...
# 491  8.080704e+07          85       9                      12
# 492  8.005812e+07          74       1                       8
# 493  5.206726e+07          78       6                      12
# 494  1.088009e+09          99       6                      19
# 495           NaN       30842    1503                    4249
#
#      N° Debitos Automáticos  Plan Familia (Millones)  Consumo (Millones)  \
# 0                         1             6.150000e+06        8.500000e+07
# ...

# %%
planta
# Out:
#          CEDULA  COD OFICINA   CODIGO GESTOR               OFICINA  \
# 0       9375240            12           9658      BOGOTÁ CHAPINERO
# 1    1023008416            73           9877       BOGOTÁ RESTREPO
# 2      41960913           228          31597        ARMENIA CENTRO
# 3    1010229345           280          36873   BOGOTÁ LOS HAYUELOS
# 4    1054920307           203           9817  PEREIRA DOSQUEBRADAS
# ..          ...           ...            ...                   ...
# 476  1019088583            51          38234       BOGOTÁ GALERIAS
# 477    80807040           634           9196  BOGOTÁ SUBA IMPERIAL
# 478    80058124           757           9863              MOSQUERA
# 479    52067261            37           9905      BOGOTÁ UNICENTRO
# 480  1088008856           206          37379  PEREIRA CRA. SEPTIMA
#
#                                 NOMBRE JORNADA  ZONA  N° Cuentas  N° CDT  \
# 0             LUIS JAVIER FUENTES LEON  NORMAL  9002         NaN     NaN
# ...

# %%
UnionEjecucionesPlanta = pd.merge(planta,ejecuciones,on="CEDULA",how="inner")

# %%
UnionEjecucionesPlanta
# Out:
#          CEDULA  COD OFICINA   CODIGO GESTOR               OFICINA  \
# 0       9375240            12           9658      BOGOTÁ CHAPINERO
# 1    1023008416            73           9877       BOGOTÁ RESTREPO
# 2      41960913           228          31597        ARMENIA CENTRO
# 3    1010229345           280          36873   BOGOTÁ LOS HAYUELOS
# 4    1054920307           203           9817  PEREIRA DOSQUEBRADAS
# ..          ...           ...            ...                   ...
# 476  1019088583            51          38234       BOGOTÁ GALERIAS
# 477    80807040           634           9196  BOGOTÁ SUBA IMPERIAL
# 478    80058124           757           9863              MOSQUERA
# 479    52067261            37           9905      BOGOTÁ UNICENTRO
# 480  1088008856           206          37379  PEREIRA CRA. SEPTIMA
#
#                                 NOMBRE JORNADA  ZONA  N° Cuentas_x  N° CDT_x  \
# 0             LUIS JAVIER FUENTES LEON  NORMAL  9002           NaN       NaN
# ...

# %%
horas
# Out:
#                Nombre  Horas Extras  Valor a Pagar  Participación
# 0          Aura Mejia          52.0            NaN            NaN
# 1   Catalina Candamil          88.0            NaN            NaN
# 2     Diego Sarmiento          88.0            NaN            NaN
# 3     Hector Mosquera          56.0            NaN            NaN
# 4       Jalima Shaker          13.0            NaN            NaN
# 5        Javier Jerez          37.0            NaN            NaN
# 6         José Campos          25.0            NaN            NaN
# 7     Lianer Barragan          69.0            NaN            NaN
# 8     Marcela Caicedo          86.0            NaN            NaN
# 9       Myriam Farfan          63.0            NaN            NaN
# 10     Nayibe Peralta          22.0            NaN            NaN
# 11     Patricia López          17.0            NaN            NaN
# 12     Rafael Montoya          18.0            NaN            NaN
# ...

# %%
horas["TotalPagar"]= horas["Horas Extras"]*5000

# %%
horas
# Out:
#                Nombre  Horas Extras  Valor a Pagar  Participación  TotalPagar
# 0          Aura Mejia          52.0            NaN            NaN    260000.0
# 1   Catalina Candamil          88.0            NaN            NaN    440000.0
# 2     Diego Sarmiento          88.0            NaN            NaN    440000.0
# 3     Hector Mosquera          56.0            NaN            NaN    280000.0
# 4       Jalima Shaker          13.0            NaN            NaN     65000.0
# 5        Javier Jerez          37.0            NaN            NaN    185000.0
# 6         José Campos          25.0            NaN            NaN    125000.0
# 7     Lianer Barragan          69.0            NaN            NaN    345000.0
# 8     Marcela Caicedo          86.0            NaN            NaN    430000.0
# 9       Myriam Farfan          63.0            NaN            NaN    315000.0
# 10     Nayibe Peralta          22.0            NaN            NaN    110000.0
# ...

# %%
prestamo
# Out:
#       NOMBRE  EDAD ESTADO CIVIL  PRESTAMO
# 0     Marcos    35      SOLTERO       NaN
# 1     Felipe    40   DIVORCIADO       NaN
# 2     Sandra    28      SOLTERO       NaN
# 3    Marcela    36      SOLTERO       NaN
# 4      Ramón    23   DIVORCIADO       NaN
# 5       Juan    51      SOLTERO       NaN
# 6    Enrique    34      SOLTERO       NaN
# 7   Fernando    48   DIVORCIADO       NaN
# 8    Natalia    26      SOLTERO       NaN
# 9     Ximena    22   DIVORCIADO       NaN
# 10  Carolina    36      SOLTERO       NaN

# %%
import numpy as np



prestamo
prestamo["Resultado"] = np.where((prestamo["EDAD"]>=29) & (prestamo["ESTADO CIVIL"]=="SOLTERO"),"Aprobado","Negado")

# %%
prestamo
# Out:
#       NOMBRE  EDAD ESTADO CIVIL  PRESTAMO Resultado
# 0     Marcos    35      SOLTERO       NaN  Aprobado
# 1     Felipe    40   DIVORCIADO       NaN    Negado
# 2     Sandra    28      SOLTERO       NaN    Negado
# 3    Marcela    36      SOLTERO       NaN  Aprobado
# 4      Ramón    23   DIVORCIADO       NaN    Negado
# 5       Juan    51      SOLTERO       NaN  Aprobado
# 6    Enrique    34      SOLTERO       NaN  Aprobado
# 7   Fernando    48   DIVORCIADO       NaN    Negado
# 8    Natalia    26      SOLTERO       NaN    Negado
# 9     Ximena    22   DIVORCIADO       NaN    Negado
# 10  Carolina    36      SOLTERO       NaN  Aprobado
